# %%
# libraries

from datetime import datetime
import os
import glob
import requests 
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Web scrapping

# %%
# download data 
# =============

link = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSc_2y5N0I67wDU38DjDh35IZSIS30rQf7_NYZhtYYGU1jJYT6_kDx4YpF-qw0LSlGsBYP8pqM_a1Pd/pubhtml#'
req = requests.get(link)
soup = BeautifulSoup(req.content, "html.parser")

# %%
tbody = soup.find_all('tbody')[0]
body = tbody.find_all('tr')

# print(tbody)
# print(body)

# %%
head_row = [i.text for i in body[0].find_all('td')]
head_row
# Out:
# ['Patient Number',
#  'State Patient Number',
#  'Date Announced',
#  'Age Bracket',
#  'Gender',
#  'Detected City',
#  'Detected District',
#  'Detected State',
#  'State_code',
#  'Current Status',
#  'Notes',
#  'Contracted from which Patient (Suspected)',
#  'Nationality',
#  'Type of transmission',
#  'Status Change Date',
#  'Source_1',
#  'Source_2',
#  'Source_3',
#  'Backup Notes',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
contents = []

for i in range(len(body)):
    contents.append([i.text for i in body[i].find_all('td')])

# %% [markdown]
# # Saving to Dataframe

# %%
p_df = pd.DataFrame(contents[2:len(contents)], columns=head_row)
p_df.head()
# Out:
#   Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 0              1             KL-TS-P1     30/01/2020          20      F
# 1              2             KL-AL-P1     02/02/2020
# 2              3             KL-KS-P1     03/02/2020
# 3              4                DL-P1     02/03/2020          45      M
# 4              5                TS-P1     02/03/2020          24      M
#
#               Detected City Detected District Detected State State_code  \
# 0                  Thrissur          Thrissur         Kerala         KL
# 1                 Alappuzha         Alappuzha         Kerala         KL
# 2                 Kasaragod         Kasaragod         Kerala         KL
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi         DL
# 4                 Hyderabad         Hyderabad      Telangana         TG
#
#   Current Status  ...                                           Source_2  \
# 0      Recovered  ...  https://weather.com/en-IN/india/news/news/2020...
# 1      Recovered  ...  https://weather.com/en-IN/india/news/news/2020...
# 2      Recovered  ...  https://twitter.com/ANI/status/122422148580539...
# 3      Recovered  ...  https://economictimes.indiatimes.com/news/poli...
# 4      Recovered  ...  https://www.indiatoday.in/india/story/coronavi...
#
#                                             Source_3  \
# 0                                 Student from Wuhan
# 1
# 2  https://weather.com/en-IN/india/news/news/2020...
# 3
# 4  https://www.thehindu.com/news/national/coronav...
#
#                                  Backup Notes
# 0                                                          None
# 1                          Student from Wuhan
# 2                          Student from Wuhan
# 3         Travel history to Italy and Austria
# 4  Travel history to Dubai, Singapore contact
#
# [5 rows x 26 columns]

# %% [markdown]
# # Data cleaning and transformations

# %%
# shape of dataframe
# ==================

p_df.shape
# Out:
# (3066, 26)

# %%
# columns
# =======

p_df.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Age Bracket', 'Gender', 'Detected City', 'Detected District',
#        'Detected State', 'State_code', 'Current Status', 'Notes',
#        'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', '', '', '', '', '', '', ''],
#       dtype='object')

# %%
# selecting important columns only
# ================================

p_df = p_df.loc[:, :'Backup Notes']

# %%
# looking for missing values 
# ==========================

p_df.isna().sum()
# Out:
# Patient Number                               0
# State Patient Number                         0
# Date Announced                               0
# Age Bracket                                  0
# Gender                                       0
# Detected City                                0
# Detected District                            0
# Detected State                               0
# State_code                                   0
# Current Status                               0
# Notes                                        0
# Contracted from which Patient (Suspected)    0
# Nationality                                  0
# Type of transmission                         0
# Status Change Date                           0
# Source_1                                     0
# Source_2                                     0
# Source_3                                     0
# Backup Notes                                 0
# dtype: int64

# %%
# no. of empty strings in each column
# ===================================

print(p_df.shape)

for i in p_df.columns:
    print(i, '\t', p_df[p_df[i]==''].shape[0])
# Out:
# (3066, 19)
# Patient Number 	 54
# State Patient Number 	 2445
# Date Announced 	 419
# Age Bracket 	 2291
# Gender 	 2139
# Detected City 	 2247
# Detected District 	 1123
# Detected State 	 419
# State_code 	 427
# Current Status 	 426
# Notes 	 797
# Contracted from which Patient (Suspected) 	 2354
# Nationality 	 2641
# Type of transmission 	 1302
# Status Change Date 	 421
# Source_1 	 437
# Source_2 	 2110
# Source_3 	 2903
# Backup Notes 	 2706

# %%
# replacing empty strings with np.nan
# ==================================-

print(p_df.shape)

p_df = p_df.replace(r'', np.nan, regex=True)
p_df.isna().sum()
# Out:
# (3066, 19)
# Patient Number                                 54
# State Patient Number                         2445
# Date Announced                                419
# Age Bracket                                  2291
# Gender                                       2139
# Detected City                                2247
# Detected District                            1123
# Detected State                                419
# State_code                                    427
# Current Status                                426
# Notes                                         797
# Contracted from which Patient (Suspected)    2354
# Nationality                                  2641
# Type of transmission                         1302
# Status Change Date                            421
# Source_1                                      437
# Source_2                                     2110
# Source_3                                     2903
# Backup Notes                                 2706
# dtype: int64

# %%
# droping empty rows (row with just row number but without patient entry
# ======================================================================

p_df.dropna(subset=['Detected State'], inplace=True)
print(p_df.shape)
p_df.isna().sum()
# Out:
# (2647, 19)
# Patient Number                                  0
# State Patient Number                         2026
# Date Announced                                  0
# Age Bracket                                  1872
# Gender                                       1720
# Detected City                                1828
# Detected District                             704
# Detected State                                  0
# State_code                                      8
# Current Status                                  7
# Notes                                         378
# Contracted from which Patient (Suspected)    1935
# Nationality                                  2222
# Type of transmission                          883
# Status Change Date                              3
# Source_1                                       18
# Source_2                                     1691
# Source_3                                     2484
# Backup Notes                                 2287
# dtype: int64

# %%
p_df.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Age Bracket', 'Gender', 'Detected City', 'Detected District',
#        'Detected State', 'State_code', 'Current Status', 'Notes',
#        'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes'],
#       dtype='object')

# %%
# rename dateframe columns 
# ========================

p_df.columns = ['_'.join(col.lower().split()) for col in p_df.columns]
p_df.rename(columns = {'contracted_from_which_patient_(suspected)':'suspected_contacted_patient'}, inplace=True)
p_df.sample(5)
# Out:
#      patient_number state_patient_number date_announced age_bracket gender  \
# 1782           1783              TN-P171     01/04/2020          39      M
# 2518           2519                  NaN     02/04/2020         NaN    NaN
# 2139           2140                  NaN     02/04/2020         NaN    NaN
# 431             432                  NaN     23/03/2020         NaN    NaN
# 1353           1354                  NaN     31/03/2020          17      F
#
#      detected_city detected_district  detected_state state_code  \
# 1782  Mettupalayam        Coimbatore      Tamil Nadu         TN
# 2518           NaN               NaN  Andhra Pradesh         AP
# 2139           NaN               NaN           Delhi         DL
# 431          Delhi               NaN           Delhi         DL
# 1353           NaN             Ajmer       Rajasthan         RJ
#
#      current_status                                notes  \
# 1782   Hospitalized  Attended Delhi Religious Conference
# 2518   Hospitalized                                  NaN
# 2139   Hospitalized                                  NaN
# 431    Hospitalized                      Details awaited
# 1353   Hospitalized       Contact of Patient, ID Unknown
#
#      suspected_contacted_patient nationality type_of_transmission  \
# 1782                          E0         NaN                  NaN
# 2518                         NaN         NaN                  NaN
# 2139                         NaN         NaN                  NaN
# 431                         P171         NaN                  TBD
# 1353                         NaN         NaN                  TBD
#
#      status_change_date                                           source_1  \
# 1782         01/04/2020  https://twitter.com/NHM_TN/status/124533236456...
# 2518         02/04/2020  https://twitter.com/ArogyaAndhra/status/124575...
# 2139         02/04/2020  https://twitter.com/ANI/status/124568322055053...
# 431          23/03/2020  https://twitter.com/ArvindKejriwal/status/1241...
# 1353         31/03/2020  https://twitter.com/ANI/status/124483610787688...
#
#                                                source_2 source_3 backup_notes
# 1782                                                NaN      NaN          NaN
# 2518                                                NaN      NaN          NaN
# 2139                                                NaN      NaN          NaN
# 431   https://twitter.com/ANI/status/124196678221620...      NaN          NaN
# 1353                                                NaN      NaN          NaN

# %%
# creating patient id column from patient number
# ===============================================

p_df['p_id'] = p_df['patient_number'].apply(lambda x : 'P'+str(x))
p_df.columns
# Out:
# Index(['patient_number', 'state_patient_number', 'date_announced',
#        'age_bracket', 'gender', 'detected_city', 'detected_district',
#        'detected_state', 'state_code', 'current_status', 'notes',
#        'suspected_contacted_patient', 'nationality', 'type_of_transmission',
#        'status_change_date', 'source_1', 'source_2', 'source_3',
#        'backup_notes', 'p_id'],
#       dtype='object')

# %%
p_df = p_df.loc[:, :'backup_notes']

# %% [markdown]
# # Saving Data

# %%
p_df.sample(5)
# Out:
#      patient_number state_patient_number date_announced age_bracket gender  \
# 422             423                  NaN     23/03/2020          27      F
# 256             257                  NaN     20/03/2020          53      M
# 953             954               KA-P75     28/03/2020          20      M
# 1533           1534               TN-P98     31/03/2020         NaN      M
# 1025           1026                  NaN     28/03/2020          48      M
#
#      detected_city detected_district  detected_state state_code  \
# 422       Vadodara          Vadodara         Gujarat         GJ
# 256         Kalyan             Thane     Maharashtra         MH
# 953      Davangere        Davanagere       Karnataka         KA
# 1533           NaN       Tirunelveli      Tamil Nadu         TN
# 1025           NaN            Indore  Madhya Pradesh         MP
#
#      current_status                                              notes  \
# 422    Hospitalized                                   Daughter of P269
# 256    Hospitalized                               Travelled from Dubai
# 953    Hospitalized                                   Cousin of KA-P42
# 1533   Hospitalized                Attended Delhi Religious Conference
# 1025   Hospitalized  contacts of earlier positive cases of #COVID19...
#
#      suspected_contacted_patient nationality type_of_transmission  \
# 422                         P269       India                Local
# 256                          NaN         NaN             Imported
# 953                         P629         NaN                Local
# 1533                          E0         NaN                  TBD
# 1025                         NaN         NaN                Local
#
#      status_change_date                                           source_1  \
# 422          23/03/2020  https://twitter.com/PTI_News/status/1241956921...
# 256          20/03/2020  https://www.thehindu.com/news/cities/mumbai/fi...
# 953          28/03/2020  https://karunadu.karnataka.gov.in/hfw/kannada/...
# 1533         31/03/2020  https://twitter.com/Vijayabaskarofl/status/124...
# 1025         28/03/2020  https://twitter.com/ANI/status/124399916468745...
#
#                                                source_2 source_3  \
# 422   https://indianexpress.com/article/india/gujara...      NaN
# 256                                                 NaN      NaN
# 953                                                 NaN      NaN
# 1533                                                NaN      NaN
# 1025  https://twitter.com/ANI/status/124399928428384...      NaN
#
#                  backup_notes
# 422                       NaN
# 256   Travel History to Dubai
# 953                       NaN
# 1533                      NaN
# 1025                      NaN

# %%
p_df.to_csv('patients_data.csv', index=False)
